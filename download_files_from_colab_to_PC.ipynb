# %%
exec(open('/content/drive/MyDrive/chatbot/train.py').read())
# Out:
# 🚀 === ENHANCED TRAINING WITH MONITORING ===
# 🔧 === ENHANCED SETUP ===
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 📁 Cache: /content/drive/MyDrive/chatbot/Model/transformers_cache
# 📁 Logs: /content/drive/MyDrive/chatbot/logs
# ✅ Found 16 files in snapshot
# ✅ Found 8 model files
# [09:31:03] ============================================================
# [09:31:04] TRAINING LOG - 2025-06-17 09:31:04
# [09:31:04] ============================================================
# [09:31:04] 🚀 Enhanced training started
# [09:31:04] MEMORY INITIAL: RAM 3.5GB (6.6%), GPU 15.5GB (70.1%)
# [09:31:04] 🧠 === LOADING MODEL WITH MONITORING ===
# [09:31:04] Model: Qwen/Qwen-7B-Chat
# [09:31:04] Cache: /content/drive/MyDrive/chatbot/Model/transformers_cache
# [09:31:04] MEMORY BEFORE LOAD: RAM 3.5GB (6.6%), GPU 15.5GB (70.1%)
# 🧹 Aggressive memory cleanup...
#    Collected 13176 objects
#    CUDA cache cleared
# ...

# %%
exec(open('/content/drive/MyDrive/chatbot/test_model_v6.py').read())
# Out:
# ⚡ === GPU OPTIMIZED TESTER V3 ===
# 🔧 === SETUP ===
# 🎮 GPU: NVIDIA L4 (22.2GB)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Found LoRA: /content/drive/MyDrive/chatbot/final_model
#
# 🚀 === LOADING MODEL ===
# 📝 Loading tokenizer...
# WARNING:transformers_modules.Qwen.Qwen-7B-Chat.93a65d34827a3cc269b727e67004743b723e2f83.modeling_qwen:The model is automatically converting to bf16 for faster inference. If you want to disable the automatic precision, please manually add bf16/fp16/fp32=True to "AutoModelForCausalLM.from_pretrained".
# WARNING:transformers_modules.Qwen.Qwen-7B-Chat.93a65d34827a3cc269b727e67004743b723e2f83.modeling_qwen:Try importing flash-attention for faster inference...
# ...
